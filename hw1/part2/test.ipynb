# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import math
# ----> 2 gaussian_weights = [[math.exp(-(a**2 + b**2)/(2*(self.sigma_s**2))) for b in range(3+1)] for a in range(3+1)]
#
# Cell In[1], line 2, in <listcomp>(.0)
#       1 import math
# ----> 2 gaussian_weights = [[math.exp(-(a**2 + b**2)/(2*(self.sigma_s**2))) for b in range(3+1)] for a in range(3+1)]
#
# Cell In[1], line 2, in <listcomp>(.0)
#       1 import math
# ----> 2 gaussian_weights = [[math.exp(-(a**2 + b**2)/(2*(self.sigma_s**2))) for b in range(3+1)] for a in range(3+1)]
#
# NameError: name 'self' is not defined
